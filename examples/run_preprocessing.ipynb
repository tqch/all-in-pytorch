# %%
import os
import sys
import torch
from skimage import data

sys.path.insert(0, os.path.abspath(".."))

from preprocessing import GaussianFilter
import matplotlib.pyplot as plt
from PIL import Image

transform = GaussianFilter(1,37,1,18)

# %%
img = data.camera()

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(transform(
    torch.tensor(img)[None,None,:,:]/255.
).numpy()[0,0], cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)
